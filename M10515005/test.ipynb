# %%
import numpy as np
import pandas as pd

# %%
table5 = pd.read_csv('/home/yuan/Dataset/kdd_2017/testing_phase1/trajectories(table 5)_test1.csv')
table6 = pd.read_csv('/home/yuan/Dataset/kdd_2017/testing_phase1/volume(table 6)_test1.csv')
table7 = pd.read_csv('/home/yuan/Dataset/kdd_2017/testing_phase1/weather (table 7)_test1.csv')
table5['starting_time'] = pd.to_datetime(table5['starting_time'])
table6['time'] = pd.to_datetime(table6['time'])
table7['date'] = pd.to_datetime(table7['date'])

# %%
table5
# Out:
#      intersection_id  tollgate_id  vehicle_id       starting_time  \
# 0                  A            2     1026631 2016-10-18 06:00:14
# 1                  C            3     1017312 2016-10-18 06:00:28
# 2                  A            2     1044671 2016-10-18 06:03:07
# 3                  A            3     1000017 2016-10-18 06:04:37
# 4                  A            2     1002850 2016-10-18 06:10:17
# 5                  A            2     1019077 2016-10-18 06:14:19
# 6                  A            3     1049060 2016-10-18 06:14:31
# 7                  C            1     1046993 2016-10-18 06:15:07
# 8                  B            3     1022126 2016-10-18 06:15:29
# 9                  B            1     1015832 2016-10-18 06:15:29
# 10                 A            3     1042861 2016-10-18 06:16:12
# 11                 A            2     1003226 2016-10-18 06:16:24
# 12                 C            1     1018917 2016-10-18 06:17:10
# ...

# %%
table6
# Out:
#                      time  tollgate_id  direction  vehicle_model  has_etc  \
# 0     2016-10-18 07:59:04            2          0              1        1
# 1     2016-10-18 07:59:31            2          0              1        1
# 2     2016-10-18 07:59:50            2          0              1        1
# 3     2016-10-18 07:32:33            3          0              1        1
# 4     2016-10-18 07:32:46            3          0              1        1
# 5     2016-10-18 07:33:41            3          0              1        1
# 6     2016-10-18 07:33:45            3          0              1        1
# 7     2016-10-18 07:33:52            3          0              1        1
# 8     2016-10-18 07:34:12            3          0              1        1
# 9     2016-10-18 07:34:52            3          0              1        1
# 10    2016-10-18 07:35:19            3          0              1        1
# 11    2016-10-18 07:35:21            3          0              1        1
# ...

# %%
table7
# Out:
#          date  hour  pressure  sea_pressure  wind_direction  wind_speed  \
# 0  2016-10-18     0    1015.2        1020.3              62         2.1
# 1  2016-10-18     3    1014.5        1019.5              37         2.5
# 2  2016-10-18     6    1012.5        1017.5             128         1.6
# 3  2016-10-18     9    1013.0        1018.0             205         0.6
# 4  2016-10-18    12    1013.8        1018.8             106         1.5
# 5  2016-10-18    15    1013.7        1018.7              90         1.9
# 6  2016-10-18    18    1012.1        1017.1             125         2.3
# 7  2016-10-18    21    1011.7        1016.7              93         1.9
# 8  2016-10-19     0    1012.7        1017.7              49         0.9
# 9  2016-10-19     3    1012.6        1017.6              94         2.8
# 10 2016-10-19     6    1010.8        1015.8              89         2.1
# 11 2016-10-19     9    1010.9        1015.9              96         1.8
# ...

# %%
df = pd.read_csv('/home/yuan/Dataset/kdd_2017/submission_sample_travelTime.csv')

# %%
df
# Out:
#     intersection_id  tollgate_id                                time_window  \
# 0                 A            2  [2016-10-18 08:00:00,2016-10-18 08:20:00)
# 1                 A            2  [2016-10-18 08:20:00,2016-10-18 08:40:00)
# 2                 A            2  [2016-10-18 08:40:00,2016-10-18 09:00:00)
# 3                 A            2  [2016-10-18 09:00:00,2016-10-18 09:20:00)
# 4                 A            2  [2016-10-18 09:20:00,2016-10-18 09:40:00)
# 5                 A            2  [2016-10-18 09:40:00,2016-10-18 10:00:00)
# 6                 A            2  [2016-10-19 08:00:00,2016-10-19 08:20:00)
# 7                 A            2  [2016-10-19 08:20:00,2016-10-19 08:40:00)
# 8                 A            2  [2016-10-19 08:40:00,2016-10-19 09:00:00)
# 9                 A            2  [2016-10-19 09:00:00,2016-10-19 09:20:00)
# 10                A            2  [2016-10-19 09:20:00,2016-10-19 09:40:00)
# ...
